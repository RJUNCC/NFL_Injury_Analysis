# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
pd.set_option("display.max_columns", 30)

# %%
conc_inj_df = pd.read_csv("../data/Concussion Injuries 2012-2014.csv")
conc_inj_df.head()
# Out:
#                                                   ID            Player  \
# 0  Aldrick Robinson - Washington Redskins vs. Tam...  Aldrick Robinson
# 1  D.J. Fluker - Tennessee Titans vs. San Diego C...       D.J. Fluker
# 2  Marquise Goodwin - Houston Texans vs. Buffalo ...  Marquise Goodwin
# 3  Bryan Stork - New England Patriots vs. Buffalo...       Bryan Stork
# 4  Lorenzo Booker - Chicago Bears vs. Indianapoli...    Lorenzo Booker
#
#                    Team                                               Game  \
# 0   Washington Redskins  Washington Redskins vs. Tampa Bay Buccaneers (...
# 1    San Diego Chargers  Tennessee Titans vs. San Diego Chargers (22/9/...
# 2         Buffalo Bills       Houston Texans vs. Buffalo Bills (28/9/2014)
# 3  New England Patriots  New England Patriots vs. Buffalo Bills (12/10/...
# 4         Chicago Bears    Chicago Bears vs. Indianapolis Colts (9/9/2012)
#
#          Date         Opposing Team          Position Pre-Season Injury?  \
# ...

# %%
head_inj_df = pd.read_csv("../data/Head Injured Players.csv")
head_inj_df.head()
# Out:
#             Player  2012/2013 - Number of Injuries  2012/2013 - Games Missed  \
# 0  DeAndre Hopkins                             NaN                       NaN
# 1     Le'Veon Bell                             NaN                       NaN
# 2   Tony Jefferson                             NaN                       NaN
# 3     James Wright                             NaN                       NaN
# 4    Joseph Randle                             NaN                       NaN
#
#    2013/2014 - Number of Injuries  2013/2014 - Games Missed  \
# 0                             1.0                       0.0
# 1                             1.0                       0.0
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    2014/2015 - Number of Injuries  2014/2015 - Games Missed  \
# 0                             NaN                       NaN
# ...

# %%
head_inj_df = head_inj_df.iloc[:, :13]
head_inj_df.head()
# Out:
#             Player  2012/2013 - Number of Injuries  2012/2013 - Games Missed  \
# 0  DeAndre Hopkins                             NaN                       NaN
# 1     Le'Veon Bell                             NaN                       NaN
# 2   Tony Jefferson                             NaN                       NaN
# 3     James Wright                             NaN                       NaN
# 4    Joseph Randle                             NaN                       NaN
#
#    2013/2014 - Number of Injuries  2013/2014 - Games Missed  \
# 0                             1.0                       0.0
# 1                             1.0                       0.0
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    2014/2015 - Number of Injuries  2014/2015 - Games Missed  \
# 0                             NaN                       NaN
# ...

# %%
match_dates = pd.read_csv("../data/Match Dates.csv")
match_dates
# Out:
#            Date  Number of Injuries  Week     Season
# 0     5/09/2012                   1     1  2012/2013
# 1    17/09/2012                   1     2  2012/2013
# 2    27/09/2012                   1     4  2012/2013
# 3    22/10/2012                   1     7  2012/2013
# 4    29/10/2012                   1     8  2012/2013
# ..          ...                 ...   ...        ...
# 153  18/12/2014                   0    16  2014/2015
# 154  20/12/2014                   0    16  2014/2015
# 155  21/12/2014                   0    16  2014/2015
# 156  22/12/2014                   0    16  2014/2015
# 157  28/12/2014                   0    17  2014/2015
#
# [158 rows x 4 columns]

# %%
nfl_teams = pd.read_csv('../data/NFL Teams.csv')
nfl_teams.head()
# Out:
#                 Team  2012/2013 - Number of Injuries  \
# 0  Arizona Cardinals                               4
# 1    Atlanta Falcons                               2
# 2   Baltimore Ravens                               9
# 3      Buffalo Bills                               3
# 4  Carolina Panthers                               3
#
#    2012/2013 - Weeks of Injury, by all its players  \
# 0                                                4
# 1                                                2
# 2                                                7
# 3                                                3
# 4                                                2
#
#    2013/2014 - Number of Injuries  \
# 0                             2.0
# 1                             3.0
# 2                             3.0
# 3                             NaN
# 4                             2.0
#
#    2013/2014 - Weeks of Injury, by all its players  \
# 0                                              2.0
# ...

# %%
nfl_teams = nfl_teams.iloc[:, :9]
nfl_teams.head()
# Out:
#                 Team  2012/2013 - Number of Injuries  \
# 0  Arizona Cardinals                               4
# 1    Atlanta Falcons                               2
# 2   Baltimore Ravens                               9
# 3      Buffalo Bills                               3
# 4  Carolina Panthers                               3
#
#    2012/2013 - Weeks of Injury, by all its players  \
# 0                                                4
# 1                                                2
# 2                                                7
# 3                                                3
# 4                                                2
#
#    2013/2014 - Number of Injuries  \
# 0                             2.0
# 1                             3.0
# 2                             3.0
# 3                             NaN
# 4                             2.0
#
#    2013/2014 - Weeks of Injury, by all its players  \
# 0                                              2.0
# ...

# %%
nfl_teams_head_inj_merged = nfl_teams.merge(
    head_inj_df, 
    how="inner", 
    left_on="Team", 
    right_on="Team(s) during concussion incidents 2012-2014"
    )

nfl_teams_head_inj_merged.head()
# Out:
#                 Team  2012/2013 - Number of Injuries_x  \
# 0  Arizona Cardinals                                 4
# 1  Arizona Cardinals                                 4
# 2  Arizona Cardinals                                 4
# 3  Arizona Cardinals                                 4
# 4  Arizona Cardinals                                 4
#
#    2012/2013 - Weeks of Injury, by all its players  \
# 0                                                4
# 1                                                4
# 2                                                4
# 3                                                4
# 4                                                4
#
#    2013/2014 - Number of Injuries_x  \
# 0                               2.0
# 1                               2.0
# 2                               2.0
# 3                               2.0
# 4                               2.0
#
#    2013/2014 - Weeks of Injury, by all its players  \
# ...

# %%
seasons = pd.read_csv("../data/Seasons.csv")
seasons.head()
# Out:
#       Season  Total Number of Injuries  Total Games Missed, by all players  \
# 0  2012/2013                       171                                 155
# 1  2013/2014                       152                                 132
# 2  2014/2015                        69                                  47
#
#    Total Weeks of Injury, all its players
# 0                                     160
# 1                                     142
# 2                                      59

# %%
conc_inj_match_dates_merged = conc_inj_df.merge(
    match_dates,
    how="inner",
    left_on="Date",
    right_on="Date"
)
conc_inj_match_dates_merged.sort_values("Date")
# Out:
#                                                     ID            Player  \
# 116  Jeff Allen - San Diego Chargers vs. Kansas Cit...        Jeff Allen
# 291  Javier Arenas - San Diego Chargers vs. Kansas ...     Javier Arenas
# 25   Jeff Maehl - Philadelphia Eagles vs. Arizona C...        Jeff Maehl
# 241  Jake Long - San Francisco 49ers vs. St. Louis ...         Jake Long
# 247  Anthony Fasano - Denver Broncos vs. Kansas Cit...    Anthony Fasano
# ..                                                 ...               ...
# 385  A.J. Jefferson - Minnesota Vikings vs. Chicago...    A.J. Jefferson
# 243  Morris Claiborne - Dallas Cowboys vs. Cincinna...  Morris Claiborne
# 306  Craig Dahl - St. Louis Rams vs. Buffalo Bills ...        Craig Dahl
# 374  Nate Livings - Dallas Cowboys vs. Cincinnati B...      Nate Livings
# 137  Early Doucet - Seattle Seahawks vs. Arizona Ca...      Early Doucet
#
#                     Team                                               Game  \
# ...
